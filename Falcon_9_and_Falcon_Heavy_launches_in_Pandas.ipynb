# %% [markdown]
# <a href="https://colab.research.google.com/github/heyrobin/Python-DataScrap-Bs4/blob/main/Falcon_9_and_Falcon_Heavy_launches_in_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
raw = pd.read_html('https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches', header=0)

# %%
A = raw[2]
A = A.drop(A.index[[1,3,5,8,10,12,14]])
A  = pd.DataFrame(A)
A.columns = ['Flight No', 'Date','Booster Version','Launch Site','Payload','Payload_Mass','Orbit','Customer','Launch Outcome','Booster landing']
A
# Out:
#     Flight No  ...            Booster landing
# 0           1  ...  Failure[9][10](parachute)
# 2           2  ...  Failure[9][14](parachute)
# 4           3  ...                 No attempt
# 6           4  ...                 No attempt
# 7           4  ...                 No attempt
# 9           5  ...                 No attempt
# 11          6  ...     Uncontrolled(ocean)[d]
# 13          7  ...             No attempt[38]
#
# [8 rows x 10 columns]

# %%
A['Time'] = A['Date'].str.split(',').str[1]
A['Date'] = A['Date'].str.split(',').str[0]
A['Time'] = A['Time'].str.split('[').str[0]
A['Launch Site'] = A['Launch Site'].str.replace(',',' ')
A['Payload'] = A['Payload'].str.split('(').str[0].str.split('[').str[0]
A['Payload_Mass'] = A['Payload_Mass'].str.split('kg').str[0]
A['Launch Outcome'] = A['Launch Outcome'].str.split('[').str[0]

import numpy as np

Z = A['Booster Version'].str.split('[').str[0]
Z_1 = A['Booster Version'].str.split(']').str[1].str.split('[').str[0]
#A["Version,Booster"] = Z +' '+ Z_1
S = Z+" " +Z_1
A['Booster Version'] = S.replace(np.nan, 'F9 v1.1 B1004', regex=True)
A['Booster landing'] = A['Booster landing'].str.split('[').str[0]
A
# Out:
#     Flight No               Date  ...      Booster landing   Time
# 0           1        4 June 2010  ...              Failure  18:45
# 2           2    8 December 2010  ...              Failure  15:43
# 4           3        22 May 2012  ...           No attempt  07:44
# 6           4     8 October 2012  ...           No attempt  00:35
# 7           4     8 October 2012  ...           No attempt  00:35
# 9           5       1 March 2013  ...           No attempt  15:10
# 11          6  29 September 2013  ...  Uncontrolled(ocean)  16:00
# 13          7    3 December 2013  ...           No attempt  22:41
#
# [8 rows x 11 columns]

# %%
B = raw[3].iloc[::2, :]

B = pd.DataFrame(B)
B.columns = ['Flight No', 'Date','Booster Version','Launch Site','Payload','Payload_Mass','Orbit','Customer','Launch Outcome','Booster landing']
B
# Out:
#     Flight No  ...             Booster landing
# 0           8  ...              No attempt[43]
# 2           9  ...   Controlled(ocean) [d][46]
# 4          10  ...    Controlled(ocean)[d][46]
# 6          11  ...              No attempt[57]
# 8          12  ...                  No attempt
# 10         13  ...  Uncontrolled(ocean)[d][64]
#
# [6 rows x 10 columns]

# %%
B['Time'] = B['Date'].str.split(',').str[1]

B['Date'] = B['Date'].str.split(',').str[0]

B['Time'] = B['Time'].str.split('[').str[0]
B['Launch Site'] = B['Launch Site'].str.replace(',',' ')
B['Payload'] = B['Payload'].str.split('(').str[0].str.split('[').str[0]
B['Payload_Mass'] = B['Payload_Mass'].str.split('kg').str[0]
B['Launch Outcome'] = B['Launch Outcome'].str.split('[').str[0]
B['Booster Version'] = B['Booster Version'].str.split('[').str[0]
B['Booster Version'] = B['Booster Version'].str.replace('1B1','1 B1')
B['Booster landing'] = B['Booster landing'].str.split('[').str[0]

# %%
B
# Out:
#     Flight No               Date  ...      Booster landing   Time
# 0           8     6 January 2014  ...           No attempt  22:06
# 2           9      18 April 2014  ...   Controlled(ocean)   19:25
# 4          10       14 July 2014  ...    Controlled(ocean)  15:15
# 6          11      5 August 2014  ...           No attempt  08:00
# 8          12   7 September 2014  ...           No attempt  05:00
# 10         13  21 September 2014  ...  Uncontrolled(ocean)  05:52
#
# [6 rows x 11 columns]

# %%
C = raw[4].iloc[::2, :]

C = pd.DataFrame(C)
C.columns = ['Flight No', 'Date','Booster Version','Launch Site','Payload','Payload_Mass','Orbit','Customer','Launch Outcome','Booster landing']
C
# Out:
#     Flight No  ...            Booster landing
# 0          14  ...       Failure (drone ship)
# 2          15  ...       Controlled(ocean)[d]
# 4          16  ...             No attempt[77]
# 6          17  ...    Failure[83](drone ship)
# 8          18  ...             No attempt[89]
# 10         19  ...  Precluded[94](drone ship)
# 12         20  ...    Success[99](ground pad)
#
# [7 rows x 10 columns]

# %%
C['Time'] = C['Date'].str.split(',').str[1]

C['Date'] = C['Date'].str.split(',').str[0]

C['Time'] = C['Time'].str.split('[').str[0]
C['Launch Site'] = C['Launch Site'].str.replace(',',' ')
C['Payload'] = C['Payload'].str.split('(').str[0].str.split('[').str[0]
C['Payload_Mass'] = C['Payload_Mass'].str.split('kg').str[0]
C['Launch Outcome'] = C['Launch Outcome'].str.split('[').str[0]
C['Booster Version'] = C['Booster Version'].str.split('[').str[0]
C['Booster Version'] = C['Booster Version'].str.replace('1B1','1 B1').str.replace('FTB','FT B')
C['Booster landing'] = C['Booster landing'].str.split('[').str[0]
C['Customer'] = C['Customer'].str.split('[').str[0]

# %%
C
# Out:
#     Flight No              Date  ...       Booster landing   Time
# 0          14   10 January 2015  ...  Failure (drone ship)  09:47
# 2          15  11 February 2015  ...     Controlled(ocean)  23:03
# 4          16      2 March 2015  ...            No attempt  03:50
# 6          17     14 April 2015  ...               Failure  20:10
# 8          18     27 April 2015  ...            No attempt  23:03
# 10         19      28 June 2015  ...             Precluded  14:21
# 12         20  22 December 2015  ...               Success  01:29
#
# [7 rows x 11 columns]

# %%
D = raw[5].iloc[::2, :]

D = pd.DataFrame(D)
D.columns = ['Flight No', 'Date','Booster Version','Launch Site','Payload','Payload_Mass','Orbit','Customer','Launch Outcome','Booster landing']
D
# Out:
#    Flight No  ...           Booster landing
# 0         21  ...       Failure(drone ship)
# 2         22  ...       Failure(drone ship)
# 4         23  ...  Success[118](drone ship)
# 6         24  ...       Success(drone ship)
# 8         25  ...  Success[133](drone ship)
# 10        26  ...   Failure[64](drone ship)
# 12        27  ...       Success(ground pad)
# 14        28  ...       Success(drone ship)
# 16   N/A [e]  ...     Precluded(drone ship)
#
# [9 rows x 10 columns]

# %%
D['Time'] = D['Date'].str.split(',').str[1]

D['Date'] = D['Date'].str.split(',').str[0]

D['Time'] = D['Time'].str.split('[').str[0]
D['Launch Site'] = D['Launch Site'].str.replace(',',' ')
D['Payload'] = D['Payload'].str.split('(').str[0].str.split('[').str[0]
D['Payload_Mass'] = D['Payload_Mass'].str.split('kg').str[0]
D['Launch Outcome'] = D['Launch Outcome'].str.split('[').str[0]
D['Booster Version'] = D['Booster Version'].str.split('[').str[0]
D['Booster Version'] = D['Booster Version'].str.replace('1B1','1 B1').str.replace('FTB','FT B')
D['Booster landing'] = D['Booster landing'].str.split('[').str[0]
D['Customer'] = D['Customer'].str.split('[').str[0]

# %%
D = D.drop(D.index[8]) #droping the faliure preflight

# %%
D
# Out:
#    Flight No             Date  ...      Booster landing   Time
# 0         21  17 January 2016  ...  Failure(drone ship)  18:42
# 2         22     4 March 2016  ...  Failure(drone ship)  23:35
# 4         23     8 April 2016  ...              Success  20:43
# 6         24       6 May 2016  ...  Success(drone ship)  05:21
# 8         25      27 May 2016  ...              Success  21:39
# 10        26     15 June 2016  ...              Failure  14:29
# 12        27     18 July 2016  ...  Success(ground pad)  04:45
# 14        28   14 August 2016  ...  Success(drone ship)  05:26
#
# [8 rows x 11 columns]

# %%
E = raw[6].iloc[::2, :]

E = pd.DataFrame(E)
E.columns = ['Flight No', 'Date','Booster Version','Launch Site','Payload','Payload_Mass','Orbit','Customer','Launch Outcome','Booster landing']
E
# Out:
#     Flight No  ...            Booster landing
# 0          29  ...   Success[154](drone ship)
# 2          30  ...        Success(ground pad)
# 4          31  ...            No attempt[165]
# 6          32  ...        Success(drone ship)
# 8          33  ...        Success(ground pad)
# 10         34  ...            No attempt[165]
# 12         35  ...        Success(ground pad)
# 14         36  ...        Success(drone ship)
# 16         37  ...        Success(drone ship)
# 18         38  ...            No attempt[165]
# 20         39  ...        Success(ground pad)
# 22         40  ...        Success(drone ship)
# 24         41  ...        Success(ground pad)
# 26         42  ...        Success(drone ship)
# 28         43  ...        Success(drone ship)
# 30         44  ...        Success(drone ship)
# 32         45  ...        Success(ground pad)
# 34         46  ...  Controlled(ocean)[d][232]
#
# [18 rows x 10 columns]

# %%
E['Time'] = E['Date'].str.split(',').str[1]

E['Date'] = E['Date'].str.split(',').str[0]

E['Time'] = E['Time'].str.split('[').str[0]
E['Launch Site'] = E['Launch Site'].str.replace(',',' ')
E['Payload'] = E['Payload'].str.split('(').str[0].str.split('[').str[0]
E['Payload_Mass'] = E['Payload_Mass'].str.split('kg').str[0]
E['Launch Outcome'] = E['Launch Outcome'].str.split('[').str[0]
E['Booster Version'] = E['Booster Version'].str.split('[').str[0]

E['Booster landing'] = E['Booster landing'].str.split('[').str[0]
E['Customer'] = E['Customer'].str.split('[').str[0]
E['Orbit'] = E['Orbit'].str.split('[').str[0]

E['Booster Version'] = E['Booster Version'].str.replace('♺', '').str.replace('FTB','FT B').str.replace('B4B','B4 B')

# %%
E
# Out:
#     Flight No              Date  ...      Booster landing      Time
# 0          29   14 January 2017  ...              Success     17:54
# 2          30  19 February 2017  ...  Success(ground pad)     14:39
# 4          31     16 March 2017  ...           No attempt     06:00
# 6          32     30 March 2017  ...  Success(drone ship)     22:27
# 8          33        1 May 2017  ...  Success(ground pad)     11:15
# 10         34       15 May 2017  ...           No attempt     23:21
# 12         35       3 June 2017  ...  Success(ground pad)     21:07
# 14         36      23 June 2017  ...  Success(drone ship)     19:10
# 16         37      25 June 2017  ...  Success(drone ship)     20:25
# 18         38       5 July 2017  ...           No attempt     23:38
# 20         39    14 August 2017  ...  Success(ground pad)     16:31
# 22         40    24 August 2017  ...  Success(drone ship)     18:51
# 24         41  7 September 2017  ...  Success(ground pad)     14:00
# ...

# %%
F = raw[7].iloc[::2, :]

F = pd.DataFrame(F)
F.columns = ['Flight No', 'Date','Booster Version','Launch Site','Payload','Payload_Mass','Orbit','Customer','Launch Outcome','Booster landing']
F
# Out:
#    Flight No  ...            Booster landing
# 0         47  ...        Success(ground pad)
# 2         48  ...  Controlled(ocean)[d][250]
# 4       FH 1  ...   Failure[259](drone ship)
# 6       FH 1  ...        Success(ground pad)
# 8         49  ...            No attempt[273]
# 10        50  ...            No attempt[283]
# 12        51  ...            No attempt[289]
# 14        52  ...            No attempt[296]
# 16        53  ...   Success[308](drone ship)
# 18        54  ...   Success[317](drone ship)
# 20        55  ...            No attempt[165]
# 22        56  ...            No attempt[165]
# 24        57  ...            No attempt[165]
# 26        58  ...   Success[346](drone ship)
# 28        59  ...   Success[354](drone ship)
# 30        60  ...   Success[360](drone ship)
# 32        61  ...   Success[363](drone ship)
# 34        62  ...   Success[365](ground pad)
# 36        63  ...   Success[372](drone ship)
# 38        64  ...   Success[375](drone ship)
# ...

# %%
F = F.drop(F.index[[2,3]]) #droping falcon heavy

# %% [markdown]
# Booster Version Column Problem

# %%
F
# Out:
#    Flight No  ...            Booster landing
# 0         47  ...        Success(ground pad)
# 2         48  ...  Controlled(ocean)[d][250]
# 8         49  ...            No attempt[273]
# 10        50  ...            No attempt[283]
# 12        51  ...            No attempt[289]
# 14        52  ...            No attempt[296]
# 16        53  ...   Success[308](drone ship)
# 18        54  ...   Success[317](drone ship)
# 20        55  ...            No attempt[165]
# 22        56  ...            No attempt[165]
# 24        57  ...            No attempt[165]
# 26        58  ...   Success[346](drone ship)
# 28        59  ...   Success[354](drone ship)
# 30        60  ...   Success[360](drone ship)
# 32        61  ...   Success[363](drone ship)
# 34        62  ...   Success[365](ground pad)
# 36        63  ...   Success[372](drone ship)
# 38        64  ...   Success[375](drone ship)
# 40        65  ...   Failure[385](ground pad)
# 42        66  ...            No attempt[388]
#
# ...

# %%
F['Time'] = F['Date'].str.split(',').str[1]

F['Date'] = F['Date'].str.split(',').str[0]

F['Time'] = F['Time'].str.split('[').str[0]
F['Launch Site'] = F['Launch Site'].str.replace(',',' ')
F['Payload'] = F['Payload'].str.split('(').str[0].str.split('[').str[0]
F['Payload_Mass'] = F['Payload_Mass'].str.split('kg').str[0].str.replace('~','')
F['Launch Outcome'] = F['Launch Outcome'].str.split('[').str[0]
F['Booster Version'] = F['Booster Version'].str.split('[').str[0]

F['Booster landing'] = F['Booster landing'].str.split('[').str[0]
F['Customer'] = F['Customer'].str.split('[').str[0]
F['Orbit'] = F['Orbit'].str.split('[').str[0]

F['Booster Version'] = F['Booster Version'].str.replace('♺', '').str.replace('FTB','FT B').str.replace('B4B','B4 B').str.replace('vyB1','vy B1')

F['Booster Version'] = F['Booster Version'].str.replace('B5B1', 'B5 B1')

# %%
F
# Out:
#    Flight No               Date  ...      Booster landing      Time
# 0         47     8 January 2018  ...  Success(ground pad)     01:00
# 2         48    31 January 2018  ...    Controlled(ocean)     21:25
# 8         49   22 February 2018  ...           No attempt     14:17
# 10        50       6 March 2018  ...           No attempt     05:33
# 12        51      30 March 2018  ...           No attempt     14:14
# 14        52       2 April 2018  ...           No attempt     20:30
# 16        53      18 April 2018  ...              Success     22:51
# 18        54        11 May 2018  ...              Success     20:14
# 20        55        22 May 2018  ...           No attempt     19:47
# 22        56        4 June 2018  ...           No attempt     04:45
# 24        57       29 June 2018  ...           No attempt     09:42
# 26        58       22 July 2018  ...              Success     05:50
# 28        59       25 July 2018  ...              Success     11:39
# ...

# %%
F['Booster Version']['F9 B5'] = 'F9 B5 B1048.1'

# %%
F
# Out:
#    Flight No               Date  ...      Booster landing      Time
# 0         47     8 January 2018  ...  Success(ground pad)     01:00
# 2         48    31 January 2018  ...    Controlled(ocean)     21:25
# 8         49   22 February 2018  ...           No attempt     14:17
# 10        50       6 March 2018  ...           No attempt     05:33
# 12        51      30 March 2018  ...           No attempt     14:14
# 14        52       2 April 2018  ...           No attempt     20:30
# 16        53      18 April 2018  ...              Success     22:51
# 18        54        11 May 2018  ...              Success     20:14
# 20        55        22 May 2018  ...           No attempt     19:47
# 22        56        4 June 2018  ...           No attempt     04:45
# 24        57       29 June 2018  ...           No attempt     09:42
# 26        58       22 July 2018  ...              Success     05:50
# 28        59       25 July 2018  ...              Success     11:39
# ...

# %%
import pandas as pd
raw = pd.read_html('https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches', header=0)

# %%
G = raw[8].iloc[::2, :]

G = pd.DataFrame(G)
G.columns = ['Flight No', 'Date','Booster Version','Launch Site','Payload','Payload_Mass','Orbit','Customer','Launch Outcome','Booster landing']
G = G.drop(G.index[[3,4,8,9]]) #droping falcon heavy
G
# Out:
#    Flight No                         Date  ... Launch Outcome      Booster landing
# 0         67   11 January 2019,15:31[398]  ...        Success  Success(drone ship)
# 2         68  22 February 2019,01:45[400]  ...        Success  Success(drone ship)
# 4         69      2 March 2019,07:49[414]  ...        Success  Success(drone ship)
# 10        70             4 May 2019,06:48  ...        Success  Success(drone ship)
# 12        71            24 May 2019,02:30  ...        Success  Success(drone ship)
# 14        72           12 June 2019,14:17  ...        Success  Success(ground pad)
# 20        73      25 July 2019,22:01[466]  ...        Success  Success(ground pad)
# 22        74     6 August 2019,23:23[473]  ...        Success      No attempt[476]
# 24        75  11 November 2019,14:56[481]  ...        Success  Success(drone ship)
# 26        76   5 December 2019,17:29[483]  ...        Success  Success(drone ship)
# ...

# %%
G['Time'] = G['Date'].str.split(',').str[1]

G['Date'] = G['Date'].str.split(',').str[0]

G['Time'] = G['Time'].str.split('[').str[0]

G['Payload'] = G['Payload'].str.split('(').str[0].str.split('[').str[0]
G['Payload_Mass'] = G['Payload_Mass'].str.split('kg').str[0].str.replace('~','')
G['Launch Outcome'] = G['Launch Outcome'].str.split('[').str[0]
G['Booster Version'] = G['Booster Version'].str.split('[').str[0]

G['Booster landing'] = G['Booster landing'].str.split('[').str[0]
G['Customer'] = G['Customer'].str.split('[').str[0]
G['Orbit'] = G['Orbit'].str.split('[').str[0]

G['Booster Version'] = G['Booster Version'].str.replace('♺', '').str.replace('FTB','FT B').str.replace('B4B','B4 B').str.replace('vyB1','vy B1')

# %%
G['Launch Site'] = G['Launch Site'].str.replace(',',' ')
G['Launch Site'] = G['Launch Site'].str.replace('SS',' ')
G['Booster Version'] = G['Booster Version'].str.replace('B5B1','B5 B1')
#G['Launch Site'] = G['Launch Site'].str.replace('_',' ')
G
# Out:
#    Flight No              Date  ...      Booster landing   Time
# 0         67   11 January 2019  ...  Success(drone ship)  15:31
# 2         68  22 February 2019  ...  Success(drone ship)  01:45
# 4         69      2 March 2019  ...  Success(drone ship)  07:49
# 10        70        4 May 2019  ...  Success(drone ship)  06:48
# 12        71       24 May 2019  ...  Success(drone ship)  02:30
# 14        72      12 June 2019  ...  Success(ground pad)  14:17
# 20        73      25 July 2019  ...  Success(ground pad)  22:01
# 22        74     6 August 2019  ...           No attempt  23:23
# 24        75  11 November 2019  ...  Success(drone ship)  14:56
# 26        76   5 December 2019  ...  Success(drone ship)  17:29
# 28        77  17 December 2019  ...  Success(drone ship)  00:10
#
# [11 rows x 11 columns]

# %%
H = raw[9].iloc[::2, :]

H = pd.DataFrame(H)
H.columns = ['Flight No', 'Date','Booster Version','Launch Site','Payload','Payload_Mass','Orbit','Customer','Launch Outcome','Booster landing']
H
# Out:
#     Flight No  ...      Booster landing
# 0          78  ...  Success(drone ship)
# 2          79  ...           No attempt
# 4          80  ...  Success(drone ship)
# 6          81  ...  Failure(drone ship)
# 8          82  ...  Success(ground pad)
# 10         83  ...  Failure(drone ship)
# 12         84  ...  Success(drone ship)
# 14         85  ...  Success(drone ship)
# 16         86  ...  Success(drone ship)
# 18         87  ...  Success(drone ship)
# 20         88  ...  Success(drone ship)
# 22         89  ...  Success(drone ship)
# 24         90  ...  Success(drone ship)
# 26         91  ...  Success(drone ship)
# 28         92  ...  Success(ground pad)
# 30         93  ...  Success(drone ship)
# 32         94  ...  Success(drone ship)
# 34         95  ...  Success(drone ship)
# 36         96  ...  Success(drone ship)
# 38         97  ...  Success(drone ship)
# 40         98  ...  Success(drone ship)
# 42         99  ...  Success(ground pad)
# ...

# %%
H['Date'] = H['Date'].str.split('[').str[0]
H['Date'] = H['Date'].str.replace(',','')
H['Date'] = H['Date'].str.replace('2020','2020,')
H['Time'] = H['Date'].str.split(',').str[1]

H['Date'] = H['Date'].str.split(',').str[0]

H['Time'] = H['Time'].str.split('[').str[0]
H['Launch Site'] = H['Launch Site'].str.replace(',',' ')
H['Launch Site'] = H['Launch Site'].str.split('[').str[0]
H['Payload'] = H['Payload'].str.split('(').str[0].str.split('[').str[0]
H['Payload_Mass'] = H['Payload_Mass'].str.split('kg').str[0].str.replace('~','')
H['Launch Outcome'] = H['Launch Outcome'].str.split('[').str[0]
H['Booster Version'] = H['Booster Version'].str.split('[').str[0]

H['Booster landing'] = H['Booster landing'].str.split('[').str[0]
H['Customer'] = H['Customer'].str.split('[').str[0]
H['Orbit'] = H['Orbit'].str.split('[').str[0]

H['Booster Version'] = H['Booster Version'].str.replace('♺', '').str.replace('FTB','FT B').str.replace('B4B','B4 B').str.replace('vyB1','vy B1')

# %%
H['Booster Version'] = H['Booster Version'].str.replace('B5B1','B5 B1')

# %%
H
# Out:
#     Flight No              Date  ...      Booster landing      Time
# 0          78    7 January 2020  ...  Success(drone ship)  02:19:21
# 2          79   19 January 2020  ...           No attempt     15:30
# 4          80   29 January 2020  ...  Success(drone ship)     14:07
# 6          81  17 February 2020  ...  Failure(drone ship)     15:05
# 8          82      7 March 2020  ...  Success(ground pad)     04:50
# 10         83     18 March 2020  ...  Failure(drone ship)     12:16
# 12         84     22 April 2020  ...  Success(drone ship)     19:30
# 14         85       30 May 2020  ...  Success(drone ship)     19:22
# 16         86       4 June 2020  ...  Success(drone ship)     01:25
# 18         87      13 June 2020  ...  Success(drone ship)     09:21
# 20         88      30 June 2020  ...  Success(drone ship)  20:10:46
# 22         89      20 July 2020  ...  Success(drone ship)     21:30
# 24         90     7 August 2020  ...  Success(drone ship)     05:12
# ...

# %%
I = raw[10].iloc[::2, :]

I = pd.DataFrame(I)
I.columns = ['Flight No', 'Date','Booster Version','Launch Site','Payload','Payload_Mass','Orbit','Customer','Launch Outcome','Booster landing']
I
# Out:
#     Flight No  ...       Booster landing
# 0         104  ...   Success(drone ship)
# 2         105  ...   Success(drone ship)
# 4         106  ...   Success(drone ship)
# 6         107  ...   Success(drone ship)
# 8         108  ...  Failure (drone ship)
# 10        109  ...   Success(drone ship)
# 12        110  ...   Success(drone ship)
# 14        111  ...   Success(drone ship)
# 16        112  ...   Success(drone ship)
# 18        113  ...   Success(drone ship)
# 20        114  ...   Success(drone ship)
# 22        115  ...   Success(drone ship)
# 24        116  ...   Success(drone ship)
# 26        117  ...   Success(drone ship)
# 28        118  ...   Success(drone ship)
# 30        119  ...   Success(drone ship)
# 32        120  ...   Success(drone ship)
# 34        121  ...   Success(drone ship)
# 36        122  ...   Success(drone ship)
# 38        123  ...   Success(ground pad)
#
# [20 rows x 10 columns]

# %%
I['Date'] = I['Date'].str.split('[').str[0]
I['Date'] = I['Date'].str.replace('2021','2021,')
I['Time'] = I['Date'].str.split(',').str[1]
I['Date'] = I['Date'].str.split(',').str[0]
I['Booster Version'] = I['Booster Version'].str.split('[').str[0]
I['Booster Version'] = I['Booster Version'].str.replace('♺', '').str.replace('FTB','FT B').str.replace('B4B','B4 B').str.replace('vyB1','vy B1')
I['Launch Site'] = I['Launch Site'].str.replace(',',' ')
I['Launch Site'] = I['Launch Site'].str.split('[').str[0]
I['Payload'] = I['Payload'].str.split('[').str[0]
I['Payload_Mass'] = I['Payload_Mass'].str.split('kg').str[0].str.replace('~','')
I['Customer'] = I['Customer'].str.split('[').str[0]

# %%
I
# Out:
#     Flight No              Date  ...       Booster landing      Time
# 0         104    8 January 2021  ...   Success(drone ship)     02:15
# 2         105   20 January 2021  ...   Success(drone ship)     13:02
# 4         106   24 January 2021  ...   Success(drone ship)     15:00
# 6         107   4 February 2021  ...   Success(drone ship)     06:19
# 8         108  16 February 2021  ...  Failure (drone ship)  03:59:37
# 10        109      4 March 2021  ...   Success(drone ship)     08:24
# 12        110     11 March 2021  ...   Success(drone ship)  08:13:29
# 14        111     14 March 2021  ...   Success(drone ship)     10:01
# 16        112     24 March 2021  ...   Success(drone ship)     08:28
# 18        113      7 April 2021  ...   Success(drone ship)     16:34
# 20        114     23 April 2021  ...   Success(drone ship)      9:49
# 22        115     29 April 2021  ...   Success(drone ship)     03:44
# 24        116        4 May 2021  ...   Success(drone ship)     19:01
# ...

# %%
spacex = pd.concat([A,B,C,D,E,F,G,H,I])
spacex.reset_index(drop=True, inplace=True)
spacex.columns = ['Flight No', 'Date','Booster_Version','Launch_Site','Payload','Payload_Mass','Orbit','Customer','Launch_Outcome','Booster_landing','Time']

spacex = spacex[['Flight No', 'Date','Time','Booster_Version','Launch_Site','Payload','Payload_Mass','Orbit','Customer','Launch_Outcome','Booster_landing']]

# %%
spacex
# Out:
#     Flight No             Date  ...   Launch_Outcome      Booster_landing
# 0           1      4 June 2010  ...          Success              Failure
# 1           2  8 December 2010  ...          Success              Failure
# 2           3      22 May 2012  ...          Success           No attempt
# 3           4   8 October 2012  ...          Success           No attempt
# 4           4   8 October 2012  ...  Partial failure           No attempt
# ..        ...              ...  ...              ...                  ...
# 119       119      26 May 2021  ...          Success  Success(drone ship)
# 120       120      3 June 2021  ...          Success  Success(drone ship)
# 121       121      6 June 2021  ...          Success  Success(drone ship)
# 122       122     17 June 2021  ...          Success  Success(drone ship)
# 123       123     30 June 2021  ...          Success  Success(ground pad)
#
# [124 rows x 11 columns]

# %%
spacex.to_csv('Falcon 9 and Falcon Heavy launches.csv')
